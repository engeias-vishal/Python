# %%
age =16
if age >= 18:
  print("Eligible")
else:
    print("Not Eligible")
# Out:
# Not Eligible
# 16

# %%
var = True
print(type(var))
# Out:
# <class 'bool'>

# %%
marks =72
if marks >= 90:
  print("A+")
elif marks >=75:
  print("B")
elif marks>=50:
    print("C")
else:
  print("Fail")
# Out:
# C

# %%
age =25
fare=80
if age>=18 and fare>=50:
  print("Condition satisfied")
# Out:
# Condition satisfied

# %%
age =25
survived=1
if age>=18:
 if survived==1:
   print("Adult advisor")
# Out:
# Adult advisor

# %% [markdown]
# #LISTS
# ordered,
# Indexed,
# Mutable,can contain duplicate values use square bracktes[]

# %%
ages=[22,38,26,35,35]
names =["Samriddhi","Shreyali","Vishal"]
mixed =[10,"python",3.5,True]
print(ages)
print(names)
print(mixed)
# Out:
# [22, 38, 26, 35, 35]
# ['Samriddhi', 'Shreyali', 'Vishal']
# [10, 'python', 3.5, True]

# %% [markdown]
# indexing and slicing

# %%
print(age[-1])
print(names[-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1768/1269253399.py in <cell line: 0>()
# ----> 1 print(age[-1])
#       2 print(names[-1])
#
# TypeError: 'int' object is not subscriptable

# %%
print(ages[::2])
# Out:
# [22, 26, 35]

# %%
print(ages[::-1])
# Out:
# [35, 35, 26, 38, 22]

# %%
ages=[22,38,26,35,35]
ages[1]=27
print(ages)
# Out:
# [22, 27, 26, 35, 35]

# %%
print(names)
# Out:
# ['Samriddhi', 'Shreyali', 'Vishal']

# %%
names.append("Vani")
print(names)
# Out:
# ['Samriddhi', 'Shreyali', 'Vishal', 'Vani']

# %%
names.insert(1,"Sachin")
print(names)
# Out:
# ['Samriddhi', 'Sachin', 'Shreyali', 'Vishal', 'Vani']

# %%
names.extend(["Neha","Rishab"])
print(names)
# Out:
# ['Samriddhi', 'Sachin', 'Shreyali', 'Vishal', 'Vani', 'Neha', 'Rishab']

# %%
names.remove("Neha")
print(names)
# Out:
# ['Samriddhi', 'Sachin', 'Shreyali', 'Vishal', 'Vani', 'Rishab']

# %%
numbers=[40,10,30,20,10]
print(len(numbers))
# Out:
# 5

# %%
print(numbers.count(10))
# Out:
# 2

# %%
print(10 in numbers)
# Out:
# True

# %%
print(max(numbers))
# Out:
# 30

# %%
print(min(numbers))
# Out:
# 10

# %%
numbers.sort()

# %%
print(numbers)
# Out:
# [10, 30]

# %%
print(sum(numbers))
# Out:
# 40

# %%
numbers.reverse()
print(numbers)
# Out:
# [30, 10]

# %% [markdown]
# Nested List

# %%
students =[
    ["samriddi",21,"CSE"],
    ["shreyali",22,"ME"],
    ["vishal",20,"ECE"]
]
print(students[0])
# Out:
# ['samriddi', 21, 'CSE']

# %%
print(students[0])
# Out:
# ['samriddi', 21, 'CSE']

# %%
print(students[0][0])
# Out:
# samriddi

# %%
print(students[2][2])
# Out:
# ECE

# %%
students[0][1]=22
print(students)
# Out:
# [['samriddi', 22, 'CSE'], ['shreyali', 22, 'ME'], ['vishal', 20, 'ECE']]

# %%
students.append(["Sachin",21,"IT"])
print(students)
# Out:
# [['samriddi', 22, 'CSE'], ['shreyali', 22, 'ME'], ['vishal', 20, 'ECE'], ['Sachin', 21, 'IT']]

# %%
students[0].append("Mathura")

# %%
print(students)
# Out:
# [['samriddi', 22, 'CSE', 'Mathura', 'Mathura'], ['shreyali', 22, 'ME'], ['vishal', 20, 'ECE'], ['Sachin', 21, 'IT']]

# %%
for student in students:
  for value in students:
   print(value)
# Out:
# a

# %%
marks=[35,62,81,45,90]
for mark in marks:
  if mark >= 50:
    print(mark,"PASS")
  else:
    print(mark,"FAIL")
# Out:
# 35 FAIL
# 62 PASS
# 81 PASS
# 45 FAIL
# 90 PASS

# %%
import pandas as pd

# %%
data ={
    "Customer ID":[101,102,103,104,104],
    "NAME":["ALICE","BOB","CHARLIE","DAVID","JOHN"],
    "AGE":[25,30,45,28,41],
    "AMOUNT":[2500,5600,7800,1500,9800],
    "RATING":[4.2,4.5,4.6,4.3,4.7]
}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#    Customer ID     NAME  AGE  AMOUNT  RATING
# 0          101    ALICE   25    2500     4.2
# 1          102      BOB   30    5600     4.5
# 2          103  CHARLIE   45    7800     4.6
# 3          104    DAVID   28    1500     4.3
# 4          104     JOHN   41    9800     4.7

# %%
df.iloc[0]
# Out:
# Customer ID      101
# NAME           ALICE
# AGE               25
# AMOUNT          2500
# RATING           4.2
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#    Customer ID     NAME  AGE  AMOUNT  RATING
# 0          101    ALICE   25    2500     4.2
# 1          102      BOB   30    5600     4.5
# 2          103  CHARLIE   45    7800     4.6

# %%
df.iloc[0:5,0:3]
# Out:
#    Customer ID     NAME  AGE
# 0          101    ALICE   25
# 1          102      BOB   30
# 2          103  CHARLIE   45
# 3          104    DAVID   28
# 4          104     JOHN   41

# %%
df.loc[df["Amount"] >500,["CUSTOMER ID","RATING"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1768/3634683501.py in <cell line: 0>()
# ----> 1 df.loc[df["Amount"] >500,["CUSTOMER ID","RATING"]]
#
# ...
